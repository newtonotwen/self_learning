# %% [markdown]
# <a href="https://colab.research.google.com/github/newtonotwen/self_learning/blob/main/Data_Visulaisasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = sns.load_dataset('diamonds')

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %% [markdown]
# # Soal 1: Scatter Plot

# %% [markdown]
# Buatlah scatterplot menggunakan Seaborn dari data df di atas, variasikan menggunakan palette yang telah disediakan sehingga didapatkan output sesuai expected.

# %%
sns.set({'figure.figsize':(13,13)})
palette = "ch:r=-.2,d=.3_r"

sns.scatterplot(data=df, x='carat', y='price',hue=df['clarity'], size=df['depth'], palette= palette)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1JLtkSpx0TfSF7fMSBcZuXaY_tNkR5LYc)

# %% [markdown]
# # Soal 2: Catplot

# %% [markdown]
# Buatlah sebuah Categorical plot dengan kind = 'boxplot', sehingga diperoleh hasil seperti expected output berikut:

# %%
with sns.axes_style(style='ticks'):
    sns.catplot(x='clarity', y='price', col= 'cut', data= df, kind= 'box', showfliers= False, ci= None)

    plt.show()

# %% [markdown]
# # Soal 3: Pair Plot

# %% [markdown]
# Ambil 300 data secara acak dari df, kemudian buat pair plotnya dari 300 data tersebut untuk kolom carat, depth, table, dan price serta markers =  ['p', 'o', 's', 'D', 'X'] sehingga dihasilkan output sesuai expected.

# %%
df = df.sample(n=300, random_state=123)

sns.pairplot(df,x_vars= ['carat','depth','table','price'],
             y_vars= ['carat','depth','table','price'],
             hue='cut',markers= ['p', 'o', 's', 'D', 'X'], corner=True)

# %% [markdown]
# # Soal 4: Joint Plot

# %% [markdown]
# Gunakan data yang sama dengan soal 3 untuk menghasilkan dua visualisasi joint plot antara carat dan price nya sesuai expected output.

# %%
with sns.axes_style('white'):
    sns.jointplot(data= df, x= 'carat', y='price', kind='kde')
sns.jointplot(data= df, x= 'carat', y='price', kind='reg')
